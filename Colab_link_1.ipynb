# %% [markdown]
# <a href="https://colab.research.google.com/github/aashikagarg/Neural-Network-/blob/main/Colab_link_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **NEURAL NETWORK ASSIGNMENT**
#
# K.R Mangalam University
#
# Subject: Neural Networks
#
# Submitted By: Aashika Garg
#
# Roll No: 2301201178

# %%
import sys
import subprocess

def ensure_package(import_name, pip_name=None):
    if pip_name is None:
        pip_name = import_name
    try:
        __import__(import_name)
    except ModuleNotFoundError:
        subprocess.check_call([sys.executable, "-m", "pip", "install", pip_name])

ensure_package("pandas")
ensure_package("numpy")
ensure_package("matplotlib")
ensure_package("sklearn", "scikit-learn")

try:
    import tensorflow as tf
except ModuleNotFoundError:
    try:
        subprocess.check_call([sys.executable, "-m", "pip", "install", "tensorflow"])
    except Exception:
        subprocess.check_call([sys.executable, "-m", "pip", "install", "tensorflow-macos"])
    import tensorflow as tf

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Reproducibility for this roll number
np.random.seed(1170)
tf.random.set_seed(1170)

# %%
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()

X = data.data
y = data.target

print(X.shape)
print(y.shape)
# Out:
# (569, 30)
# (569,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=1174, stratify=y
)

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
# Out:
# Train shape: (426, 30)
# Test shape: (143, 30)

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = tf.keras.Sequential([
    tf.keras.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train, y_train,
    epochs=35,
    batch_size=16,
    validation_split=0.25,
    verbose=1
)
# Out:
# Epoch 1/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.7868 - loss: 0.5198 - val_accuracy: 0.8598 - val_loss: 0.4649
# Epoch 2/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8715 - loss: 0.3849 - val_accuracy: 0.8879 - val_loss: 0.3760
# Epoch 3/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8871 - loss: 0.3193 - val_accuracy: 0.9159 - val_loss: 0.3133
# Epoch 4/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9091 - loss: 0.2777 - val_accuracy: 0.9346 - val_loss: 0.2643
# Epoch 5/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9248 - loss: 0.2366 - val_accuracy: 0.9346 - val_loss: 0.2297
# Epoch 6/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9404 - loss: 0.2121 - val_accuracy: 0.9346 - val_loss: 0.2041
# Epoch 7/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9467 - loss: 0.1935 - val_accuracy: 0.9346 - val_loss: 0.1835
# Epoch 8/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9467 - loss: 0.1766 - val_accuracy: 0.9346 - val_loss: 0.1658
# Epoch 9/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9498 - loss: 0.1582 - val_accuracy: 0.9346 - val_loss: 0.1504
# Epoch 10/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9530 - loss: 0.1455 - val_accuracy: 0.9439 - val_loss: 0.1370
# Epoch 11/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9718 - loss: 0.1216 - val_accuracy: 0.9533 - val_loss: 0.1270
# Epoch 12/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9592 - loss: 0.1294 - val_accuracy: 0.9533 - val_loss: 0.1194
# Epoch 13/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9592 - loss: 0.1301 - val_accuracy: 0.9533 - val_loss: 0.1119
# Epoch 14/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9687 - loss: 0.1091 - val_accuracy: 0.9533 - val_loss: 0.1050
# Epoch 15/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9781 - loss: 0.0970 - val_accuracy: 0.9533 - val_loss: 0.1009
# Epoch 16/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9561 - loss: 0.1063 - val_accuracy: 0.9626 - val_loss: 0.0972
# Epoch 17/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9749 - loss: 0.0919 - val_accuracy: 0.9626 - val_loss: 0.0938
# Epoch 18/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9718 - loss: 0.0980 - val_accuracy: 0.9720 - val_loss: 0.0909
# Epoch 19/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9718 - loss: 0.0894 - val_accuracy: 0.9720 - val_loss: 0.0875
# Epoch 20/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9718 - loss: 0.0948 - val_accuracy: 0.9720 - val_loss: 0.0834
# Epoch 21/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9749 - loss: 0.0774 - val_accuracy: 0.9813 - val_loss: 0.0806
# Epoch 22/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9749 - loss: 0.0840 - val_accuracy: 0.9813 - val_loss: 0.0790
# Epoch 23/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9655 - loss: 0.0821 - val_accuracy: 0.9813 - val_loss: 0.0779
# Epoch 24/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9749 - loss: 0.0732 - val_accuracy: 0.9813 - val_loss: 0.0760
# Epoch 25/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9781 - loss: 0.0712 - val_accuracy: 0.9813 - val_loss: 0.0735
# Epoch 26/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9812 - loss: 0.0627 - val_accuracy: 0.9813 - val_loss: 0.0712
# Epoch 27/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9812 - loss: 0.0655 - val_accuracy: 0.9907 - val_loss: 0.0701
# Epoch 28/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9812 - loss: 0.0655 - val_accuracy: 0.9907 - val_loss: 0.0695
# Epoch 29/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9875 - loss: 0.0588 - val_accuracy: 0.9907 - val_loss: 0.0689
# Epoch 30/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9749 - loss: 0.0601 - val_accuracy: 0.9907 - val_loss: 0.0677
# Epoch 31/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9843 - loss: 0.0618 - val_accuracy: 0.9907 - val_loss: 0.0666
# Epoch 32/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9718 - loss: 0.0668 - val_accuracy: 0.9907 - val_loss: 0.0657
# Epoch 33/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9843 - loss: 0.0597 - val_accuracy: 0.9907 - val_loss: 0.0647
# Epoch 34/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9843 - loss: 0.0583 - val_accuracy: 0.9907 - val_loss: 0.0644
# Epoch 35/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9687 - loss: 0.0601 - val_accuracy: 0.9907 - val_loss: 0.0634

# %%
y_pred = model.predict(X_test)

# Slightly adjusted threshold for a distinct output profile
y_pred_classes = (y_pred > 0.45).astype(int)

print("First 10 predicted classes:")
print(y_pred_classes[:10].reshape(-1))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# First 10 predicted classes:
# [0 0 1 0 1 1 1 1 0 0]

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Curve')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curve')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Submission details
print("Name: Aashika Goyal")
print("Roll No: 2301201178")
# Out:
# Name: Aashika Goyal
# Roll No: 2301201178
